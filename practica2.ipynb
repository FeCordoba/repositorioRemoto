# %% [markdown]
# Ejercicio 1

# %%
import string 
text = """Beautiful is better than ugly.
Explicit is better than implicit.
Simple is better than complex.
Complex is better than complicated.
Flat is better than nested.
Sparse is better than dense.
Readability counts.
Special cases aren't special enough to break the rules.
Although practicality beats purity.
Errors should never pass silently.
Unless explicitly silenced.
In the face of ambiguity, refuse the temptation to guess.
There should be one-- and preferably only one --obvious way 
to do it.
Although that way may not be obvious at first unless you're 
Dutch.
Now is better than never.
Although never is often better than *right* now.
If the implementation is hard to explain, it's a bad idea.
If the implementation is easy to explain, it may be a good 
idea.
Namespaces are one honking great idea -- let's do more of 
those!"""

list1 = text.split('.')
print(f'total de lineas:', len(list1))
list2 = text.split()
print(f'total de palabras:', len(list2))
prom = len(list2)/len(list1)
print(f'promedio de palabras por linea:', prom)
print()
print(f'lineas por encima del promedio:', prom)
for line in list1:
    if len(line.split())>prom:
        print(line)
# Out:
# total de lineas: 19
# total de palabras: 137
# promedio de palabras por linea: 7.2105263157894735
#
# lineas por encima del promedio: 7.2105263157894735
#
# Special cases aren't special enough to break the rules
#
# In the face of ambiguity, refuse the temptation to guess
#
# There should be one-- and preferably only one --obvious way
# to do it
#
# Although that way may not be obvious at first unless you're
# Dutch
#
# Although never is often better than *right* now
#
# If the implementation is hard to explain, it's a bad idea
#
# If the implementation is easy to explain, it may be a good
# idea
#
# Namespaces are one honking great idea -- let's do more of
# those!

# %% [markdown]
# Ejercicio 2

# %%
import string
playlist = [
{"title": "Bohemian Rhapsody", "duration": "5:55"},
{"title": "Hotel California", "duration": "6:30"},
{"title": "Stairway to Heaven", "duration": "8:02"},
{"title": "Imagine", "duration": "3:07"},
{"title": "Smells Like Teen Spirit", "duration": "5:01"},
{"title": "Billie Jean", "duration": "4:54"},
{"title": "Hey Jude", "duration": "7:11"},
{"title": "Like a Rolling Stone", "duration": "6:13"},
]   

def a_segundos(cancion):
    minutos, segundos = cancion["duration"].split(":")
    return int(minutos) * 60 + int(segundos)

total_segs = sum(a_segundos(c) for c in playlist)

min_total = total_segs // 60
seg_total = total_segs % 60

print(f'Duracion total: {min_total}m {seg_total}s')

mas_larga = max(playlist, key=a_segundos)
mas_corta = min(playlist, key=a_segundos)

print(f'Canción más larga: "{mas_larga["title"]}" ({mas_larga["duration"]})')
print(f'Canción más corta: "{mas_corta["title"]}" ({mas_corta["duration"]})')
# Out:
# Duracion total: 46m 53s
# Canción más larga: "Stairway to Heaven" (8:02)
# Canción más corta: "Imagine" (3:07)

# %% [markdown]
# Ejercicio 3

# %%
import string 

review = """La película sigue a un grupo de astronautas que 
viajan a Marte
en una misión de rescate. El capitán Torres lidera al equipo 
a través
de tormentas solares y fallos en el sistema de navegación. Al 
llegar
a Marte descubren que la base está abandonada y los 
suministros
destruidos. Torres decide sacrificar la nave nodriza para 
salvar
al equipo y logran volver a la Tierra en una cápsula de 
emergencia.
El final revela que Torres sobrevivió gracias a un pasaje 
secreto."""

spoilers = input('Ingrese las palabras spoilers (separadas por coma) : ').split(',')
print(spoilers)

def es (palabra):
    ok = False 
    index = 0
    while not ok and index<len(spoilers):
        if palabra.casefold().strip() == spoilers[index].casefold().strip():
            ok = True 
        index += 1
    return ok


text = review.split()
index = 0
for palabra in text:
    if es(palabra):
        text[index] = '*' * len(palabra)
    index += 1
    
print(' '.join(text))
# Out:
# Ingrese las palabras spoilers (separadas por coma) :  marte, torres
# ['marte', ' torres']
# La película sigue a un grupo de astronautas que viajan a ***** en una misión de rescate. El capitán ****** lidera al equipo a través de tormentas solares y fallos en el sistema de navegación. Al llegar a ***** descubren que la base está abandonada y los suministros destruidos. ****** decide sacrificar la nave nodriza para salvar al equipo y logran volver a la Tierra en una cápsula de emergencia. El final revela que ****** sobrevivió gracias a un pasaje secreto.

# %% [markdown]
# Ejercicio 10

# %%
rounds = [
{
'theme': 'Entrada',
'scores': {
'Valentina': {'judge_1': 8, 'judge_2': 7,
'judge_3': 9},
'Mateo': {'judge_1': 7, 'judge_2': 8,
'judge_3': 7},
'Camila': {'judge_1': 9, 'judge_2': 9,
'judge_3': 8},
'Santiago': {'judge_1': 6, 'judge_2': 7,
'judge_3': 6},
'Lucía': {'judge_1': 8, 'judge_2': 8,
'judge_3': 8},
}
},
{
'theme': 'Plato principal',
'scores': {
'Valentina': {'judge_1': 9, 'judge_2': 9,
'judge_3': 8},
'Mateo': {'judge_1': 8, 'judge_2': 7,
'judge_3': 9},
'Camila': {'judge_1': 7, 'judge_2': 6,
'judge_3': 7},
'Santiago': {'judge_1': 9, 'judge_2': 8,
'judge_3': 8},
'Lucía': {'judge_1': 7, 'judge_2': 8,
'judge_3': 7},
}
},
{
'theme': 'Postre',
'scores': {
'Valentina': {'judge_1': 7, 'judge_2': 8,
'judge_3': 7},
'Mateo': {'judge_1': 9, 'judge_2': 9,
'judge_3': 8},
'Camila': {'judge_1': 8, 'judge_2': 7,
'judge_3': 9},
'Santiago': {'judge_1': 7, 'judge_2': 7,
'judge_3': 6},
'Lucía': {'judge_1': 9, 'judge_2': 9,
'judge_3': 9},
}
},
{
'theme': 'Cocina internacional',
'scores': {
'Valentina': {'judge_1': 8, 'judge_2': 9,
'judge_3': 9},
'Mateo': {'judge_1': 7, 'judge_2': 6,
'judge_3': 7},
'Camila': {'judge_1': 9, 'judge_2': 8,
'judge_3': 8},
'Santiago': {'judge_1': 8, 'judge_2': 9, 
'judge_3': 7},
    'Lucía': {'judge_1': 7, 'judge_2': 7,
'judge_3': 8},
}
},
{
'theme': 'Final libre',
'scores': {
'Valentina': {'judge_1': 9, 'judge_2': 8,
'judge_3': 9},
'Mateo': {'judge_1': 8, 'judge_2': 9,
'judge_3': 8},
'Camila': {'judge_1': 7, 'judge_2': 7,
'judge_3': 7},
'Santiago': {'judge_1': 9, 'judge_2': 9,
'judge_3': 9},
'Lucía': {'judge_1': 8, 'judge_2': 8,
'judge_3': 7},
}
}
]

index = 0
TEMA = 'theme'

tabla_final = {}   #  Se ira mostrando como progreso y al final 
tabla_aux = {}    #  Para guardar res de c/u x ronda y sacar ganador x ronda

for ronda in rounds:
    for participante, jueces in ronda["scores"].items():
        puntaje = sum(jueces.values())
        tabla_aux[participante] = puntaje
        if participante not in tabla_final:
            tabla_final[participante] = {   #  Inicializo el {} de un cocinero si es la primera vez que anota sus puntos
                'total': 0, 
                'ganadas': 0,
                'mejor': 0
            }
            tabla_final[participante]['total'] += puntaje
            tabla_final[participante]['mejor'] = max(tabla_final[participante]['mejor'], puntaje)
        else: 
            tabla_final[participante]['total'] += puntaje
            tabla_final[participante]['mejor'] = max(tabla_final[participante]['mejor'], puntaje)  
                                                  
    nombre_ganador = max(tabla_aux, key=tabla_aux.get)   #  Itera por clave pero con el criterio de los valores
    puntaje_ganador = tabla_aux[nombre_ganador]
    tabla_final[nombre_ganador]['ganadas'] += 1
 
    print(f'Ronda {index+1} - {rounds[index][TEMA]}:')    #  Por ej: Ronda 1 - Entrada: 
    print(f'Ganador: {nombre_ganador} ({puntaje_ganador})')
    print(f'Cocinero        Total  Ganadas  Mejor')
    for p in tabla_final:
        print(f'{p}       {tabla_final[p]['total']}       {tabla_final[p]['ganadas']}        {tabla_final[p]['mejor']}   \n')        
               #  Va mostrando progreso 

    index += 1
    print('')

for participante in tabla_final:
    tabla_final[participante]['promedio'] = tabla_final[participante]['total'] / len(rounds)

print('')

tabla_final = dict(sorted(tabla_final.items(), key=lambda x:x[1]['total'], reverse=True))  #  Ordena tabla decrecientemente


print('Tabla de posiciones final: ')
print(f'Cocinero        Total  Ganadas  Mejor  Promedio')
for p in tabla_final:
    print(f'{p}       {tabla_final[p]['total']}       {tabla_final[p]['ganadas']}        {tabla_final[p]['mejor']}      {tabla_final[p]['promedio']} \n')
# Out:
# Ronda 1 - Entrada:
# Ganador: Camila (26)
# Cocinero        Total  Ganadas  Mejor
# Valentina       24       0        24
#
# Mateo       22       0        22
#
# Camila       26       1        26
#
# Santiago       19       0        19
#
# Lucía       24       0        24
#
#
# Ronda 2 - Plato principal:
# Ganador: Valentina (26)
# Cocinero        Total  Ganadas  Mejor
# Valentina       50       1        26
#
# Mateo       46       0        24
#
# Camila       46       1        26
#
# Santiago       44       0        25
#
# Lucía       46       0        24
#
#
# Ronda 3 - Postre:
# Ganador: Lucía (27)
# Cocinero        Total  Ganadas  Mejor
# Valentina       72       1        26
#
# Mateo       72       0        26
#
# Camila       70       1        26
#
# Santiago       64       0        25
#
# Lucía       73       1        27
#
#
# Ronda 4 - Cocina internacional:
# Ganador: Valentina (26)
# Cocinero        Total  Ganadas  Mejor
# Valentina       98       2        26
#
# ...
